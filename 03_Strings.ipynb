# %%
### strings ##

my_string = "Mi otro string"
my_other_string = "Mi otro string"

print(len(my_string))
print(len(my_other_String))
print(my_string + "" my_other_string)

my_new_line_string_="Este es un String/n con salto de linea"
print(my_new_line_string)

my_tab_string = "/+ Este es un string con tabulacion"
print(my_tab_string)

my_scape_string = "//+Este es un string //n escapado"
print(my_scape_string)

# formateo

name,surname,age = "Aaron", "Bucio",15
print("mi nombre es {} {} y mi edad es {}".format(name,surname,age))
print("mi nombre es %s %s y mi edad es %d" % (name,surname,age))
print("mi nombre es "+ name + " " + surname + " y mi edad es " + str (age))
print("mi nombre es {name} {surname} y mi edad es {age}")

# desempaquetado de caracteristicas

language = "python"
a,b,c,d,e,f = language
print(a)
print(e)

# divicion

language_slice = language [1:3]
print(language_slice)
language_slice = language [1:]
print(language_slice)
language_slice = [-2]
print(language_slice)
language_slice = language [0:6:2]
print(language_slice)

#reverse
reversed_language = language[:-1]   #eso invierte la palabra
print(reversed_language)

#funciones de lenguaje
#print(language.capitalize())
#print(language.upper()) #todas las letras mayusculas
#print(language.count("t")) #cuantas t tiene
#print(language.isnumeric)  #python es numerica false
#print(language.lower())   #lower significa minusculas
#print(language.lower().isupper())
#print(language.startwicth("py"))
#print("Py" == "py") # no es lo mismo
