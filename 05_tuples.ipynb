# %%
# tuples #

# definicion #

my_tuple = tuple
my_other_tuple = ()

my_tuple = (35, 1.77, "aaron", "bucio", "alumno")
my_other_tuple = (35, 60, 30)

print(my_tuple)
print(type(my_tuple))

# acceso a elementos y busqueda

print (my_tuple[0])
print(my_tuple[-1])

#print(my_tuple[5]) # indexerror
#print(my_tuple[-6]) # indexerror

print(my_tuple.count("aaron"))
print(my_tuple.index("bucio"))
print(my_tuple.index("alumno"))

#my_tuple[1]= 1.80 # `tuple` obect does not support item assignment # las tuplas no se peden modificar su contenido
# concatenacion

my_sum_tuple = my_tuple + my_other_tuple
print(my_sum_tuple)

#subtuplas
print(my_sum_tuple [3:6])
#tupla mutable con convercion a lista

my_tuple = list (my_tuple)
print(type(my_tuple))

my_tuple = (35, 1.77, "aaron", "bucio", "alumno")
my_other_tuple = (35, 60, 30)

my_tuple [4] = "CECyTEM"
my_tuple.insert (1, "azul")
my_tuple =tuple (my_tuple)
print(my_tuple)
print(type(my_tuple))

#eliminacion
# del my_tuple [2] typeError: `tuple` obect does not support item deletion

del my_tuple

# print (my_tuple) nameError: name `my_tuple` is not
